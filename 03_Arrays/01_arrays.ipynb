# %% [markdown]
# ARRAY:
#
# Phase 1 (Foundation)
# ────────────────────
# What is an Array?
# Memory Representation
# Indexing
# Traversal
# Insertion
# Deletion
# Reverse
# Rotation
#
# Phase 2 (Basic Interview Problems)
# ────────────────────
# Linear Search
# Find Maximum
# Find Minimum
# Second Largest
# Count Frequency
# Remove Duplicates
#
# Phase 3 (Intermediate)
# ────────────────────
# Prefix Sum
# Suffix Sum
# Prefix Maximum
# Prefix Minimum
# Difference Array
#
# Phase 4 (Patterns)
# ────────────────────
# Two Pointer
# Sliding Window
#
# Phase 5 (Advanced)
# ────────────────────
# Kadane Algorithm
# Dutch National Flag
# Moore Voting
# Binary Search on Arrays
#
# Phase 6 (LeetCode)
# ────────────────────
# Easy
#
# ↓
#
# Medium
#
# ↓
#
# Hard
